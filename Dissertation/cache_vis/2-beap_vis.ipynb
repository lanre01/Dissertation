# %%
# use to visuallise cache

import pandas as pd 
import matplotlib.pyplot as plt

# %%
# visualise 2-beap 
# visuallise push
df = pd.read_csv("../bench_results_cache/2-nbeap.csv")
df.head()

otherCols = ["op", "size"]

colsToPlot = [col  for col in df.columns if not col in otherCols]
df_pushRandom = df[df["op"] == "PushRandom"] 
df_pushRandom = df_pushRandom.sort_values("size")

plt.figure(figsize=(10,6))
plt.title(f"Plot of 2-beap push random performance overtime")
plt.xlabel("Input Size")
plt.ylabel("time in ns")
plt.xscale("log", base=2)
plt.yscale("log", base=2)
# plt.ylim(bottom=0)

x = df_pushRandom["size"].to_numpy()

for col in colsToPlot:
    y = df_pushRandom[col].to_numpy()
    plt.plot(x, y, marker="o", label=col)
    #print(y)

plt.grid(True, which="both", linestyle=":")
plt.legend()
plt.tight_layout()
plt.show()

# %%
# visualise 2-beap 
# visuallise extract
df = pd.read_csv("../bench_results_cache/2-nbeap.csv")
df.head()

otherCols = ["op", "size"]

colsToPlot = [col  for col in df.columns if not col in otherCols]
df_pushRandom = df[df["op"] == "Extract"] 
df_pushRandom = df_pushRandom.sort_values("size")

plt.figure(figsize=(10,6))
plt.title(f"Plot of 2-beap extract performance overtime")
plt.xlabel("Input Size")
plt.ylabel("time in ns")
plt.xscale("log", base=2)
plt.yscale("log", base=2)
# plt.ylim(bottom=0)

x = df_pushRandom["size"].to_numpy()

for col in colsToPlot:
    y = df_pushRandom[col].to_numpy()
    plt.plot(x, y, marker="o", label=col)
    print(y)

plt.grid(True, which="both", linestyle=":")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# [8.33826e+03 2.64818e+04 7.70964e+04 2.18320e+05 6.11702e+05 1.72416e+06
#  5.62049e+06 1.89112e+07 6.09483e+07 2.00269e+08 6.68478e+08 2.53826e+09
#  1.05484e+10]
# [7.35006e+03 2.32420e+04 6.73327e+04 1.95243e+05 5.51390e+05 1.55730e+06
#  5.12268e+06 1.68925e+07 5.38607e+07 1.81301e+08 5.83062e+08 2.22851e+09
#  8.39535e+09]
# [8.02107e+03 2.48356e+04 7.35874e+04 2.07709e+05 5.83171e+05 1.65307e+06
#  4.68518e+06 1.45362e+07 4.54847e+07 1.58621e+08 5.65273e+08 1.56590e+09
#  5.00202e+09]
# [7.35743e+03 2.21978e+04 7.00767e+04 1.99965e+05 5.71137e+05 1.60422e+06
#  4.52166e+06 1.35971e+07 4.68033e+07 1.63204e+08 5.60669e+08 1.77237e+09
#  5.40528e+09]
# [7.78025e+03 2.36907e+04 7.43108e+04 2.15451e+05 6.11921e+05 1.72157e+06
#  4.87090e+06 1.46281e+07 4.66403e+07 1.70808e+08 5.73657e+08 1.73573e+09
#  5.33440e+09]
